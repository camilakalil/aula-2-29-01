# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
l=[0,4,5]
l
# Out:
# [0, 4, 5]

# %%
l[1]
# Out:
# 1

# %%
i=1

# %%
l[i]
# Out:
# 4

# %%
len(l)
# Out:
# 3

# %%
l[len(l)-1]
# Out:
# 5

# %%
l[-1]
# Out:
# 5

# %%
soma=0

# %%
soma += l[0]
soma += l[1]
soma += l[2]
soma
# Out:
# 9

# %%
for x in l:
      print(x+2)
# Out:
# 2
# 6
# 7

# %%
soma=0
for x in l:
      soma += x
    
soma
# Out:
# 9

# %%
y=0
if (x>1):
    y=y+x
else:
    y=1

# %%
l=[0,1,2,3,4,5,6,7]

# %%
l[0]
# Out:
# 0

# %%
l[6]
# Out:
# 6

# %%
for x in l:
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
l=[0,3,5,6,7,10,12,13]
valor = 6
pos = 0
for i in l:
    if i == valor:
        print ("Encontrado o valor ", valor, "na posição", pos)
    else:
        print ("Não encontrado")
    pos +=1
# Out:
# Não encontrado
# Não encontrado
# Não encontrado
# Encontrado o valor  6 na posição 3
# Não encontrado
# Não encontrado
# Não encontrado
# Não encontrado
